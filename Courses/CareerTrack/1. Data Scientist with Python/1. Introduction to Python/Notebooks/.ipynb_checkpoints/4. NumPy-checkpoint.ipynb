# %% [markdown]
# # 1. NumPy Basics

# %% [markdown]
# ### 1. NumPy array

# %%
# Create list baseball
baseball = [180, 215, 210, 210, 188, 176, 209, 200]

# Import the numpy package as np
import numpy as np

# Create a numpy array from baseball: np_baseball
np_baseball = np.array(baseball)

# Print out type of np_baseball
print(type(np_baseball))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ### 2. Baseball players' height

# %% [markdown]
# Web-Scraping the info ( not part of the course )

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from IPython.display import display_html

# %%
url="http://wiki.stat.ucla.edu/socr/index.php/SOCR_Data_MLB_HeightsWeights"

# %%
df = pd.read_html(url,header=0)
df[1]
# Out:
#                  Name Team        Position  Height(inches)  Weight(pounds)  \
# 0       Adam_Donachie  BAL         Catcher              74           180.0
# 1           Paul_Bako  BAL         Catcher              74           215.0
# 2     Ramon_Hernandez  BAL         Catcher              72           210.0
# 3        Kevin_Millar  BAL   First_Baseman              72           210.0
# 4         Chris_Gomez  BAL   First_Baseman              73           188.0
# ...               ...  ...             ...             ...             ...
# 1029    Brad_Thompson  STL  Relief_Pitcher              73           190.0
# 1030    Tyler_Johnson  STL  Relief_Pitcher              74           180.0
# 1031   Chris_Narveson  STL  Relief_Pitcher              75           205.0
# 1032    Randy_Keisler  STL  Relief_Pitcher              75           190.0
# 1033      Josh_Kinney  STL  Relief_Pitcher              73           195.0
#
#         Age
# 0     22.99
# 1     34.69
# 2     30.78
# 3     35.43
# ...

# %%
height = df[1]["Height(inches)"]
height
# Out:
# 0       74
# 1       74
# 2       72
# 3       72
# 4       73
#         ..
# 1029    73
# 1030    74
# 1031    75
# 1032    75
# 1033    73
# Name: Height(inches), Length: 1034, dtype: int64

# %%
height_in = np.array(height)
height_in
# Out:
# array([74, 74, 72, ..., 75, 75, 73], dtype=int64)

# %%
weight = df[1]["Weight(pounds)"]
weight
# Out:
# 0       180.0
# 1       215.0
# 2       210.0
# 3       210.0
# 4       188.0
#         ...
# 1029    190.0
# 1030    180.0
# 1031    205.0
# 1032    190.0
# 1033    195.0
# Name: Weight(pounds), Length: 1034, dtype: float64

# %%
weight_lb = np.array(weight)
weight_lb
# Out:
# array([180., 215., 210., ..., 205., 190., 195.])

# %%
age = df[1]["Age"]
age
# Out:
# 0       22.99
# 1       34.69
# 2       30.78
# 3       35.43
# 4       35.71
#         ...
# 1029    25.08
# 1030    25.73
# 1031    25.19
# 1032    31.01
# 1033    27.92
# Name: Age, Length: 1034, dtype: float64

# %%
position = df[1]["Position"]
position
# Out:
# 0              Catcher
# 1              Catcher
# 2              Catcher
# 3        First_Baseman
# 4        First_Baseman
#              ...
# 1029    Relief_Pitcher
# 1030    Relief_Pitcher
# 1031    Relief_Pitcher
# 1032    Relief_Pitcher
# 1033    Relief_Pitcher
# Name: Position, Length: 1034, dtype: object

# %%
# height is available as a regular list
# Import numpy
import numpy as np

# Create a numpy array from height_in: np_height_in
np_height_in = np.array(height_in)

# Print out np_height_in
print(np_height_in)

# Convert np_height_in to m: np_height_m
np_height_m = np_height_in*0.0254
print(np_height_m)

# Print np_height_m
# Out:
# [74 74 72 ... 75 75 73]
# [1.8796 1.8796 1.8288 ... 1.905  1.905  1.8542]

# %% [markdown]
# ### 3. Baseball players' BMI

# %%
# height and weight are available as regular lists

# Import numpy
import numpy as np

# Create array from height_in with metric units: np_height_m
np_height_m = np.array(height_in) * 0.0254

# Create array from weight_lb with metric units: np_weight_kg
np_weight_kg = np.array(weight_lb) * 0.453592 

# Calculate the BMI: bmi
bmi=np_weight_kg/np_height_m**2
print(bmi)

# Print out bmi
# Out:
# [23.11037639 27.60406069 28.48080465 ... 25.62295933 23.74810865
#  25.72686361]

# %% [markdown]
# ### 4. Lightweight Baseball players

# %%
# height and weight are available as a regular lists

# Import numpy
import numpy as np

# Calculate the BMI: bmi
np_height_m = np.array(height_in) * 0.0254
np_weight_kg = np.array(weight_lb) * 0.453592
bmi = np_weight_kg / np_height_m ** 2

# Create the light array
light = np.array(bmi<21)

# Print out light
print(light)

# Print out BMIs of all baseball players whose BMI is below 21
print(bmi[light])
# Out:
# [False False False ... False False False]
# [20.54255679 20.54255679 20.69282047 20.69282047 20.34343189 20.34343189
#  20.69282047 20.15883472 19.4984471  20.69282047 20.9205219 ]
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':

# %% [markdown]
# ### 5. Subsetting NumPy Arrays

# %%
# height and weight are available as a regular lists

# Import numpy
import numpy as np

# Store weight and height lists as numpy arrays
np_weight_lb = np.array(weight_lb)
np_height_in = np.array(height_in)

# Print out the weight at index 50
print(np_weight_lb[50])

# Print out sub-array of np_height_in: index 100 up to and including index 110
print(np_height_in[100:111])
# Out:
# 195.0
# [73 72 74 73 74 72 73 69 72 73 75]

# %% [markdown]
# # 2. 2D NumPy

# %% [markdown]
# ### 1. 2D NumPy Array

# %%
# Create baseball, a list of lists
baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]]

# Import numpy
import numpy as np

# Create a 2D numpy array from baseball: np_baseball
np_baseball = np.array(baseball)

# Print out the type of np_baseball
print(type(np_baseball))

# Print out the shape of np_baseball
print(np_baseball.shape)
# Out:
# <class 'numpy.ndarray'>
# (4, 2)

# %% [markdown]
# ### 2. Baseball Data in 2D Form

# %%
# baseball is available as a regular list of lists

# Import numpy package
import numpy as np

# Create a 2D numpy array from baseball: np_baseball
np_baseball = np.array(baseball)

# Print out the shape of np_baseball
print(np_baseball.shape)
# Out:
# (4, 2)

# %% [markdown]
# ### 3. Subsetting 2D NumPy arrays

# %%
baseball = [ [height[i],weight[i]] for i in range(0,len(height)) ]
baseball
# Out:
# [[74, 180.0],
#  [74, 215.0],
#  [72, 210.0],
#  [72, 210.0],
#  [73, 188.0],
#  [69, 176.0],
#  [69, 209.0],
#  [71, 200.0],
#  [76, 231.0],
#  [71, 180.0],
#  [73, 188.0],
#  [73, 180.0],
#  [74, 185.0],
#  [74, 160.0],
#  [69, 180.0],
#  [70, 185.0],
#  [72, 197.0],
#  [73, 189.0],
#  [75, 185.0],
#  [78, 219.0],
#  [79, 230.0],
#  [76, 205.0],
#  [74, 230.0],
#  [76, 195.0],
#  [72, 180.0],
#  [71, 192.0],
#  [75, 225.0],
#  [77, 203.0],
#  [74, 195.0],
#  [73, 182.0],
#  [74, 188.0],
#  [78, 200.0],
#  [73, 180.0],
#  [75, 200.0],
#  [73, 200.0],
#  [75, 245.0],
#  [75, 240.0],
#  [74, 215.0],
#  [69, 185.0],
#  [71, 175.0],
#  [74, 199.0],
#  [73, 200.0],
#  [73, 215.0],
#  [76, 200.0],
#  [74, 205.0],
#  [74, 206.0],
#  [70, 186.0],
#  [72, 188.0],
#  [77, 220.0],
#  [74, 210.0],
#  [70, 195.0],
#  [76, 244.0],
#  [75, 195.0],
#  [73, 200.0],
#  [75, 200.0],
#  [76, 212.0],
#  [76, 224.0],
#  [78, 210.0],
#  [74, 205.0],
#  [74, 220.0],
#  [76, 195.0],
#  [77, 200.0],
# ...

# %%
# baseball is available as a regular list of lists

# Import numpy package
import numpy as np

# Create np_baseball (2 cols)
np_baseball = np.array(baseball)

# Print out the 50th row of np_baseball
print(np_baseball[49][:])

# Select the entire second column of np_baseball: np_weight_lb
np_weight_lb = np_baseball[:,1]

# Print out height of 124th player
print(np_baseball[123,0])
# Out:
# [ 74. 210.]
# 76.0

# %% [markdown]
# ### 4. 2D Arithmetic

# %%
baseball = [ [height[i], weight[i], age[i]] for i in range(0,len(height))]
baseball
# Out:
# [[74, 180.0, 22.99],
#  [74, 215.0, 34.69],
#  [72, 210.0, 30.78],
#  [72, 210.0, 35.43],
#  [73, 188.0, 35.71],
#  [69, 176.0, 29.39],
#  [69, 209.0, 30.77],
#  [71, 200.0, 35.07],
#  [76, 231.0, 30.19],
#  [71, 180.0, 27.05],
#  [73, 188.0, 23.88],
#  [73, 180.0, 26.96],
#  [74, 185.0, 23.29],
#  [74, 160.0, 26.11],
#  [69, 180.0, 27.55],
#  [70, 185.0, 34.27],
#  [72, 197.0, 30.0],
#  [73, 189.0, 27.99],
#  [75, 185.0, 22.38],
#  [78, 219.0, 22.89],
#  [79, 230.0, 25.76],
#  [76, 205.0, 36.33],
#  [74, 230.0, 31.17],
#  [76, 195.0, 32.31],
#  [72, 180.0, 31.03],
#  [71, 192.0, 29.26],
#  [75, 225.0, 29.47],
#  [77, 203.0, 32.46],
#  [74, 195.0, 35.67],
#  [73, 182.0, 25.89],
#  [74, 188.0, 26.55],
#  [78, 200.0, 24.17],
#  [73, 180.0, 26.69],
#  [75, 200.0, 25.13],
#  [73, 200.0, 27.9],
#  [75, 245.0, 30.17],
#  [75, 240.0, 31.36],
#  [74, 215.0, 30.99],
#  [69, 185.0, 32.24],
#  [71, 175.0, 27.61],
#  [74, 199.0, 28.2],
#  [73, 200.0, 28.85],
#  [73, 215.0, 24.21],
# ...

# %%
# Create np_baseball (3 cols)
np_baseball = np.array(baseball)

# Create numpy array: conversion
conversion=np.array([0.0254,0.453592,1])

# Print out product of np_baseball and conversion
print(np_baseball*conversion)
# Out:
# [[ 1.8796  81.64656 22.99   ]
#  [ 1.8796  97.52228 34.69   ]
#  [ 1.8288  95.25432 30.78   ]
#  ...
#  [ 1.905   92.98636 25.19   ]
#  [ 1.905   86.18248 31.01   ]
#  [ 1.8542  88.45044 27.92   ]]

# %% [markdown]
# # 3. NumPy: Basic Stats

# %% [markdown]
# ### 1. Average v/s Median

# %%
# np_baseball is available

# Import numpy
import numpy as np

# Create np_height_in from np_baseball
np_height_in = np_baseball[:,0]

# Print out the mean of np_height_in
print(np.mean(np_height_in))

# Print out the median of np_height_in
print(np.median(np_height_in))
# Out:
# 73.6972920696325
# 74.0

# %% [markdown]
# In the DataCamp course, there were outliers which had absurd values in the height column, which resulted the mean value to be above 1500 but the median was 74.0 . Hence, median serves as a good medium for outlier detection

# %% [markdown]
# ### 2. Explore the baseball data

# %%
# np_baseball is available

# Import numpy
import numpy as np

# Print mean height (first column)
avg = np.mean(np_baseball[:,0])
print("Average: " + str(avg))

# Print median height. Replace 'None'
med = np.median(np_baseball[:,0])
print("Median: " + str(med))

# Print out the standard deviation on height. Replace 'None'
stddev = np.std(np_baseball[:,0])
print("Standard Deviation: " + str(stddev))

# Print out correlation between first and second column. Replace 'None'
corr = np.corrcoef(np_baseball[:,0],np_baseball[:,1])
print("Correlation: " + str(corr))
# Out:
# Average: 73.6972920696325
# Median: 74.0
# Standard Deviation: 2.304703041620148
# Correlation: [[ 1. nan]
#  [nan nan]]

# %% [markdown]
# The np_baseball contains NaN data hence correlation is giving the same. This needs to be [ RECHECKED ]

# %% [markdown]
# ### 3. Blend it all together

# %%
position.value_counts()
# Out:
# Relief_Pitcher       315
# Starting_Pitcher     221
# Outfielder           194
# Catcher               76
# Second_Baseman        58
# First_Baseman         55
# Shortstop             52
# Third_Baseman         45
# Designated_Hitter     18
# Name: Position, dtype: int64

# %%
# heights and positions are available as lists

# Import numpy
import numpy as np

# Convert positions and heights to numpy arrays: np_positions, np_heights
np_positions = np.array(position)
np_heights = np.array(height)

# Heights of the Designated_Hitter: dh_heights
dh_heights = np_heights[np_positions=='Designated_Hitter']

# Heights of the other players: other_heights
other_heights = np_heights[np_positions!='Designated_Hitter']

# Print out the median height of Designated_Hitter. Replace 'None'
print("Median height of Designated_Hitter: " + str(np.median(dh_heights)))

# Print out the median height of other players. Replace 'None'
print("Median height of other players: " + str(np.median(other_heights)))
# Out:
# Median height of Designated_Hitter: 74.5
# Median height of other players: 74.0
